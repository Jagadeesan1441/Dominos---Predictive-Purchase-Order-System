# %% [markdown]
# #PIZZA INGRIDIENTS

# %%
import pandas as pd

# %%
pizza_ingridients =pd.read_excel("/content/Pizza_ingredients.xlsx")
pizza_ingridients
# Out:
#     pizza_name_id                         pizza_name  pizza_ingredients  \
# 0       bbq_ckn_l         The Barbecue Chicken Pizza  Barbecued Chicken
# 1       bbq_ckn_l         The Barbecue Chicken Pizza        Red Peppers
# 2       bbq_ckn_l         The Barbecue Chicken Pizza      Green Peppers
# 3       bbq_ckn_l         The Barbecue Chicken Pizza           Tomatoes
# 4       bbq_ckn_l         The Barbecue Chicken Pizza         Red Onions
# ..            ...                                ...                ...
# 513  veggie_veg_s  The Vegetables + Vegetables Pizza      Green Peppers
# 514  veggie_veg_s  The Vegetables + Vegetables Pizza         Red Onions
# 515  veggie_veg_s  The Vegetables + Vegetables Pizza           Zucchini
# 516  veggie_veg_s  The Vegetables + Vegetables Pizza            Spinach
# 517  veggie_veg_s  The Vegetables + Vegetables Pizza             Garlic
#
#      Items_Qty_In_Grams
# 0                  40.0
# 1                  15.0
# 2                  20.0
# ...

# %%
pizza_ingridients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pizza_name_id       518 non-null    object
#  1   pizza_name          518 non-null    object
#  2   pizza_ingredients   518 non-null    object
#  3   Items_Qty_In_Grams  514 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 16.3+ KB

# %%
pizza_ingridients.shape
# Out:
# (518, 4)

# %%
pizza_ingridients.describe()
# Out:
#        Items_Qty_In_Grams
# count          514.000000
# mean            30.564202
# std             30.351623
# min              5.000000
# 25%             10.000000
# 50%             20.000000
# 75%             40.000000
# max            200.000000

# %%
pizza_ingridients.isnull().sum()
# Out:
# pizza_name_id         0
# pizza_name            0
# pizza_ingredients     0
# Items_Qty_In_Grams    4
# dtype: int64

# %%
pizza_ingridients_null_rows=pizza_ingridients[pizza_ingridients.isna().any(axis=1)]
pizza_ingridients_null_rows
# Out:
#     pizza_name_id            pizza_name   pizza_ingredients  \
# 24   brie_carre_s  The Brie Carre Pizza  Caramelized Onions
# 149    hawaiian_l    The Hawaiian Pizza          Sliced Ham
# 152    hawaiian_m    The Hawaiian Pizza          Sliced Ham
# 155    hawaiian_s    The Hawaiian Pizza          Sliced Ham
#
#      Items_Qty_In_Grams
# 24                  NaN
# 149                 NaN
# 152                 NaN
# 155                 NaN

# %%
pizza_ingridients.loc[(pizza_ingridients["pizza_name"]=="The Brie Carre Pizza") & (pizza_ingridients["Items_Qty_In_Grams"].isnull()),"Items_Qty_In_Grams"]=20.0
pizza_ingridients.loc[(pizza_ingridients["pizza_name_id"]=="hawaiian_s") & (pizza_ingridients["Items_Qty_In_Grams"].isnull()),"Items_Qty_In_Grams"]=20.0
pizza_ingridients.loc[(pizza_ingridients["pizza_name_id"]=="hawaiian_m") & (pizza_ingridients["Items_Qty_In_Grams"].isnull()),"Items_Qty_In_Grams"]=40.0
pizza_ingridients.loc[(pizza_ingridients["pizza_name_id"]=="hawaiian_l") & (pizza_ingridients["Items_Qty_In_Grams"].isnull()),"Items_Qty_In_Grams"]=60.0

# %%
pizza_ingridients.isnull().sum()
# Out:
# pizza_name_id         0
# pizza_name            0
# pizza_ingredients     0
# Items_Qty_In_Grams    0
# dtype: int64

# %%
pizza_ingridients.duplicated().sum()
# Out:
# np.int64(0)

# %%
pizza_ingridients.nunique()
# Out:
# pizza_name_id         91
# pizza_name            32
# pizza_ingredients     64
# Items_Qty_In_Grams    17
# dtype: int64

# %%
pizza_ingridients["pizza_name"].value_counts()
# Out:
# pizza_name
# The Greek Pizza                               30
# The Spinach Supreme Pizza                     24
# The Mexicana Pizza                            24
# The Southwest Chicken Pizza                   24
# The Vegetables + Vegetables Pizza             24
# The California Chicken Pizza                  21
# The Mediterranean Pizza                       21
# The Italian Vegetables Pizza                  21
# The Italian Supreme Pizza                     18
# The Sicilian Pizza                            18
# The Pepper Salami Pizza                       18
# The Barbecue Chicken Pizza                    18
# The Chicken Pesto Pizza                       18
# The Italian Capocollo Pizza                   18
# The Chicken Alfredo Pizza                     18
# The Calabrese Pizza                           18
# The Spinach Pesto Pizza                       18
# The Spicy Italian Pizza                       18
# The Spinach and Feta Pizza                    15
# ...

# %%
pizza_ingridients["pizza_name_id"].value_counts()
# Out:
# pizza_name_id
# spinach_supr_s    8
# spinach_supr_l    8
# spinach_supr_m    8
# veggie_veg_l      8
# southw_ckn_m      8
#                  ..
# prsc_argla_s      3
# prsc_argla_m      3
# pepperoni_s       2
# pepperoni_l       2
# pepperoni_m       2
# Name: count, Length: 91, dtype: int64

# %%
pd.set_option('display.max_rows',None)

# %%
pizza_ingridients["pizza_ingredients"].value_counts()
# Out:
# pizza_ingredients
# Garlic                        57
# Tomatoes                      56
# Red Onions                    41
# Red Peppers                   30
# Spinach                       24
# Mushrooms                     21
# Artichokes                    18
# Pepperoni                     16
# Chicken                       15
# Mozzarella Cheese             15
# Feta Cheese                   14
# Green Olives                  12
# Capocollo                     12
# Kalamata Olives               11
# Pesto Sauce                    9
# Asiago Cheese                  9
# Jalapeno Peppers               9
# Green Peppers                  9
# Goat Cheese                    6
# Pineapple                      6
# Sun-dried Tomatoes             6
# Zucchini                       6
# Corn                           6
# Chipotle Sauce                 6
# Fontina Cheese                 6
# Cilantro                       6
# Beef Chuck Roast               5
# Bacon                          4
# ...

# %%
pizza_ingridients["pizza_ingredients"] = pizza_ingridients["pizza_ingredients"].replace("?duja Salami", "Nduja Salami")

# %%
pizza_ingridients.dtypes
# Out:
# pizza_name_id          object
# pizza_name             object
# pizza_ingredients      object
# Items_Qty_In_Grams    float64
# dtype: object

# %%
pizza_ingridients["Items_Qty_In_Grams"]=pizza_ingridients["Items_Qty_In_Grams"].astype(int)

# %%
pizza_ingridients.dtypes
# Out:
# pizza_name_id         object
# pizza_name            object
# pizza_ingredients     object
# Items_Qty_In_Grams     int64
# dtype: object

# %% [markdown]
# #PIZZA SALES

# %%
pizza_sales_df=pd.read_excel("/content/Pizza_Sale.xlsx")

# %%
pizza_sales_df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity           order_date  \
# 0         1         1     hawaiian_m         1  2015-01-01 00:00:00
# 1         2         2  classic_dlx_m         1  2015-01-01 00:00:00
# 2         3         2  five_cheese_l         1  2015-01-01 00:00:00
# 3         4         2    ital_supr_l         1  2015-01-01 00:00:00
# 4         5         2     mexicana_m         1  2015-01-01 00:00:00
#
#   order_time  unit_price  total_price pizza_size pizza_category  \
# 0   11:38:36       13.25        13.25          M        Classic
# 1   11:57:40       16.00        16.00          M        Classic
# 2   11:57:40       18.50        18.50          L         Veggie
# 3   11:57:40       20.75        20.75          L        Supreme
# 4   11:57:40       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
pizza_sales_df.shape
# Out:
# (48620, 12)

# %%
pizza_sales_df.columns
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
pizza_sales_df.isnull().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id        16
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           7
# pizza_size            0
# pizza_category       23
# pizza_ingredients    13
# pizza_name            7
# dtype: int64

# %%
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Five Cheese Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Veggie'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Mexicana Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Veggie'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Spinach Pesto Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Veggie'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Spinach and Feta Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Veggie'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Greek Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Classic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Napolitana Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Classic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Pepperoni Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Classic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Hawaiian Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Classic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Italian Capocollo Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Classic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Barbecue Chicken Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Chicken'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Chicken Alfredo Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Chicken'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Prosciutto and Arugula Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Supreme'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Brie Carre Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Supreme'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Pepper Salami Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Supreme'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Sicilian Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Supreme'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Spicy Italian Pizza') & (pizza_sales_df['pizza_category'].isnull()), 'pizza_category'] = 'Supreme'

# %%
pizza_sales_df.loc[(pizza_sales_df['pizza_name_id'].isin(['pepperoni_l', 'pepperoni_s'])) & (pizza_sales_df['pizza_name'].isnull()), 'pizza_name'] = 'The Pepperoni Pizza'
pizza_sales_df.loc[(pizza_sales_df['pizza_name_id'] == 'hawaiian_s') & (pizza_sales_df['pizza_name'].isnull()), 'pizza_name'] = 'The Hawaiian Pizza'
pizza_sales_df.loc[(pizza_sales_df['pizza_name_id'] == 'big_meat_s') & (pizza_sales_df['pizza_name'].isnull()), 'pizza_name'] = 'The Big Meat Pizza'
pizza_sales_df.loc[(pizza_sales_df['pizza_name_id'] == 'spicy_ital_m') & (pizza_sales_df['pizza_name'].isnull()), 'pizza_name'] = 'The Spicy Italian Pizza'
pizza_sales_df.loc[(pizza_sales_df['pizza_name_id'] == 'sicilian_s') & (pizza_sales_df['pizza_name'].isnull()), 'pizza_name'] = 'The Sicilian Pizza'
pizza_sales_df.loc[(pizza_sales_df['pizza_name_id'] == 'mexicana_l') & (pizza_sales_df['pizza_name'].isnull()), 'pizza_name'] = 'The Mexicana Pizza'

# %%
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Five Cheese Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Mozzarella Cheese, Provolone Cheese, Smoked Gouda Cheese, Romano Cheese, Blue Cheese, Garlic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Four Cheese Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Ricotta Cheese, Gorgonzola Piccante Cheese, Mozzarella Cheese, Parmigiano Reggiano Cheese, Garlic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Green Garden Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Spinach, Mushrooms, Tomatoes, Green Olives, Feta Cheese'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Hawaiian Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Sliced Ham, Pineapple, Mozzarella Cheese'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The California Chicken Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Chicken, Artichokes, Spinach, Garlic, Jalapeno Peppers, Fontina Cheese, Gouda Cheese'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Southwest Chicken Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Chicken, Tomatoes, Red Peppers, Red Onions, Jalapeno Peppers, Corn, Cilantro, Chipotle Sauce'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Chicken Alfredo Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Chicken, Red Onions, Red Peppers, Mushrooms, Asiago Cheese, Alfredo Sauce'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Spinach and Feta Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Spinach, Mushrooms, Red Onions, Feta Cheese, Garlic'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Prosciutto and Arugula Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Prosciutto di San Daniele, Arugula, Mozzarella Cheese'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Pepperoni, Mushroom, and Peppers Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Pepperoni, Mushrooms, Green Peppers'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Italian Vegetables Pizza') & (pizza_sales_df['pizza_ingredients'].isnull()), 'pizza_ingredients'] = 'Eggplant, Artichokes, Tomatoes, Zucchini, Red Peppers, Garlic, Pesto Sauce'

# %%
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Five Cheese Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'five_cheese_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Soppressata Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'soppressata_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Greek Pizza') & (pizza_sales_df['pizza_size'] == 'S') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'the_greek_s'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Four Cheese Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'four_cheese_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Napolitana Pizza') & (pizza_sales_df['pizza_size'] == 'S') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'napolitana_s'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Thai Chicken Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'thai_ckn_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Green Garden Pizza') & (pizza_sales_df['pizza_size'] == 'S') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'green_garden_s'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Spinach Supreme Pizza') & (pizza_sales_df['pizza_size'] == 'S') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'spinach_supr_s'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Pepperoni Pizza') & (pizza_sales_df['pizza_size'] == 'S') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'pepperoni_s'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Barbecue Chicken Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'bbq_ckn_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Hawaiian Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'hawaiian_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Italian Supreme Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'ital_supr_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The California Chicken Pizza') & (pizza_sales_df['pizza_size'] == 'L') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'cali_ckn_l'
pizza_sales_df.loc[(pizza_sales_df['pizza_name'] == 'The Pepper Salami Pizza') & (pizza_sales_df['pizza_size'] == 'M') & (pizza_sales_df['pizza_name_id'].isnull()), 'pizza_name_id'] = 'peppr_salami_m'

# %%
pizza_sales_df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          7
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
pizza_sales_df['total_price'] = pizza_sales_df['total_price'].fillna(pizza_sales_df['quantity'] * pizza_sales_df['unit_price'])

# %%
pizza_sales_df.columns
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
pizza_sales_df["pizza_category"].value_counts()
# Out:
# pizza_category
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: count, dtype: int64

# %%
pizza_sales_df["pizza_name_id"].value_counts()
# Out:
# pizza_name_id
# big_meat_s        1811
# thai_ckn_l        1365
# five_cheese_l     1359
# four_cheese_l     1273
# classic_dlx_m     1159
# spicy_ital_l      1088
# hawaiian_s        1001
# southw_ckn_l       993
# bbq_ckn_l          967
# bbq_ckn_m          926
# ital_supr_m        920
# pepperoni_m        918
# cali_ckn_m         914
# hawaiian_l         896
# cali_ckn_l         895
# mexicana_l         844
# classic_dlx_s      786
# pepperoni_s        739
# ital_supr_l        735
# sicilian_s         731
# ital_cpcllo_l      715
# pepperoni_l        712
# ckn_alfredo_m      697
# peppr_salami_l     680
# veggie_veg_m       630
# sicilian_l         596
# green_garden_s     593
# prsc_argla_m       585
# four_cheese_m      577
# pep_msh_pep_s      570
# sicilian_m         560
# spinach_fet_m      558
# napolitana_l       557
# calabrese_m        554
# the_greek_xl       544
# southw_ckn_m       526
# cali_ckn_s         493
# ital_veggie_m      483
# brie_carre_s       480
# ...

# %%
pizza_sales_df["pizza_ingredients"].value_counts()
# Out:
# pizza_ingredients
# Pepperoni, Mushrooms, Red Onions, Red Peppers, Bacon                                                 2416
# Barbecued Chicken, Red Peppers, Green Peppers, Tomatoes, Red Onions, Barbecue Sauce                  2372
# Sliced Ham, Pineapple, Mozzarella Cheese                                                             2370
# Mozzarella Cheese, Pepperoni                                                                         2369
# Chicken, Pineapple, Tomatoes, Red Peppers, Thai Sweet Chilli Sauce                                   2315
# Chicken, Artichoke, Spinach, Garlic, Jalapeno Peppers, Fontina Cheese, Gouda Cheese                  2300
# Capocollo, Tomatoes, Goat Cheese, Artichokes, Peperoncini verdi, Garlic                              1887
# Coarse Sicilian Salami, Tomatoes, Green Olives, Luganega Sausage, Onions, Garlic                     1887
# Chicken, Tomatoes, Red Peppers, Red Onions, Jalapeno Peppers, Corn, Cilantro, Chipotle Sauce         1885
# ...

# %%
pizza_sales_df["pizza_ingredients"]=pizza_sales_df["pizza_ingredients"].replace({"?duja Salami, Pancetta, Tomatoes, Red Onions, Friggitello Peppers, Garlic":"Nduja Salami, Pancetta, Tomatoes, Red Onions, Friggitello Peppers, Garlic","Chicken, Artichoke, Spinach, Garlic, Jalapeno Peppers, Fontina Cheese, Gouda Cheese":"Chicken, Artichokes, Spinach, Garlic, Jalapeno Peppers, Fontina Cheese, Gouda Cheese"})

# %%
pizza_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
pizza_sales_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pizza_sales_df.head(5)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity           order_date  \
# 0         1         1     hawaiian_m         1  2015-01-01 00:00:00
# 1         2         2  classic_dlx_m         1  2015-01-01 00:00:00
# 2         3         2  five_cheese_l         1  2015-01-01 00:00:00
# 3         4         2    ital_supr_l         1  2015-01-01 00:00:00
# 4         5         2     mexicana_m         1  2015-01-01 00:00:00
#
#   order_time  unit_price  total_price pizza_size pizza_category  \
# 0   11:38:36       13.25        13.25          M        Classic
# 1   11:57:40       16.00        16.00          M        Classic
# 2   11:57:40       18.50        18.50          L         Veggie
# 3   11:57:40       20.75        20.75          L        Supreme
# 4   11:57:40       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
pizza_sales_df["order_date"]=pd.to_datetime(pizza_sales_df["order_date"])

# %%
pizza_sales_df["order_time"].head(5)
# Out:
# 0    11:38:36
# 1    11:57:40
# 2    11:57:40
# 3    11:57:40
# 4    11:57:40
# Name: order_time, dtype: object

# %%
pizza_sales_df['order_time'] = pd.to_datetime(pizza_sales_df['order_time'], format='%H:%M:%S').dt.strftime('%I:%M:%S %p')

# %%
pizza_sales_df.head(5)
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date   order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01  11:38:36 AM
# 1         2         2  classic_dlx_m         1 2015-01-01  11:57:40 AM
# 2         3         2  five_cheese_l         1 2015-01-01  11:57:40 AM
# 3         4         2    ital_supr_l         1 2015-01-01  11:57:40 AM
# 4         5         2     mexicana_m         1 2015-01-01  11:57:40 AM
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
newmerged_df1=pd.merge(pizza_sales_df,pizza_ingridients,left_on=["pizza_name_id","pizza_name"],right_on=["pizza_name_id","pizza_name"],how="inner")
newmerged_df1.shape
# Out:
# (267576, 14)

# %%
newmerged_df1.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date   order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01  11:38:36 AM
# 1         1         1     hawaiian_m         1 2015-01-01  11:38:36 AM
# 2         1         1     hawaiian_m         1 2015-01-01  11:38:36 AM
# 3         2         2  classic_dlx_m         1 2015-01-01  11:57:40 AM
# 4         2         2  classic_dlx_m         1 2015-01-01  11:57:40 AM
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       13.25        13.25          M        Classic
# 2       13.25        13.25          M        Classic
# 3       16.00        16.00          M        Classic
# 4       16.00        16.00          M        Classic
#
#                                  pizza_ingredients_x  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1           Sliced Ham, Pineapple, Mozzarella Cheese
# ...

# %%
newmerged_df1.drop("pizza_ingredients_y",axis=1,inplace=True)

# %%
newmerged_df1.rename(columns={"pizza_ingredients_x":"pizza_ingredients"},inplace=True)

# %%
newmerged_df1.duplicated().sum()
# Out:
# np.int64(80205)

# %%
newmerged_df1.drop_duplicates(inplace=True)

# %%
newmerged_df1.dtypes
# Out:
# pizza_id                       int64
# order_id                       int64
# pizza_name_id                 object
# quantity                       int64
# order_date            datetime64[ns]
# order_time                    object
# unit_price                   float64
# total_price                  float64
# pizza_size                    object
# pizza_category                object
# pizza_ingredients             object
# pizza_name                    object
# Items_Qty_In_Grams             int64
# dtype: object

# %%
from statistics import mean, median, mode, stdev, variance

for col in ["unit_price", "total_price", "quantity"]:
    print(f"{col} →")
    print(f"  Mean: {mean(newmerged_df1[col])}")
    print(f"  Median: {median(newmerged_df1[col])}")
    print(f"  Mode: {mode(newmerged_df1[col])}")
    print(f"  Standard Deviation: {stdev(newmerged_df1[col])}")
    print(f"  Variance: {variance(newmerged_df1[col])}")
# Out:
# unit_price →
#   Mean: 16.91440777921877
#   Median: 16.75
#   Mode: 20.75
#   Standard Deviation: 3.5714389351430813
#   Variance: 12.755176067455949
# total_price →
#   Mean: 17.24491516830246
#   Median: 16.75
#   Mode: 20.75
#   Standard Deviation: 4.419967986693745
#   Variance: 19.536117003397557
# quantity →
#   Mean: 1.019250577730812
#   Median: 1
#   Mode: 1
#   Standard Deviation: 0.1415753053767403
#   Variance: 0.02004356709251727

# %%
def outliers_removal(newmerged_df):
  for i in newmerged_df[["unit_price", "total_price", "quantity"]]:
    q1=newmerged_df[i].quantile(0.15)
    q3=newmerged_df[i].quantile(0.85)
    iqr=q3-q1
    lower_limit=q1-1.5*iqr
    upper_limit=q3+1.5*iqr
    newmerged_df=newmerged_df[(newmerged_df[i]>=lower_limit) & (newmerged_df[i]<=upper_limit)]
  return newmerged_df

# %%
df=outliers_removal(newmerged_df1)

# %%
newmerged_df1.shape
# Out:
# (187371, 13)

# %%
df.shape
# Out:
# (183722, 13)

# %%
df.to_csv('newcleanedpizzadf')

# %%
df.describe()
# Out:
#             pizza_id       order_id  quantity                     order_date  \
# count  183722.000000  183722.000000  183722.0                         183722
# mean    24311.794679   10701.946991       1.0  2015-06-28 21:30:52.063443712
# min         1.000000       1.000000       1.0            2015-01-01 00:00:00
# 25%     12154.000000    5337.000000       1.0            2015-03-30 00:00:00
# 50%     24271.500000   10664.000000       1.0            2015-06-28 00:00:00
# 75%     36490.000000   16110.000000       1.0            2015-09-29 00:00:00
# max     48620.000000   21350.000000       1.0            2015-12-31 00:00:00
# std     14040.500364    6182.257661       0.0                            NaN
#
#           unit_price    total_price  Items_Qty_In_Grams
# count  183722.000000  183722.000000       183722.000000
# mean       16.894623      16.894623           37.720197
# min         9.750000       9.750000            5.000000
# ...

# %%
df.isnull().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id         0
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           0
# pizza_size            0
# pizza_category        0
# pizza_ingredients     0
# pizza_name            0
# Items_Qty_In_Grams    0
# dtype: int64

# %% [markdown]
# #Feature Engineering

# %%
# Adding Holiday Indicator to the Data
import holidays

# using US holidays
us_holidays = holidays.US()

# Creating a 'holiday' column that indicates if the order_date was a holiday
df['holiday'] = df['order_date'].apply(lambda x: 1 if x in us_holidays else 0)

# Checking if the holiday flag works
df[['order_date', 'holiday']].head()
# Out:
#   order_date  holiday
# 0 2015-01-01        1
# 1 2015-01-01        1
# 2 2015-01-01        1
# 3 2015-01-01        1
# 6 2015-01-01        1

# %%
#weekend priorities
df['workingday'] = df['order_date'].dt.dayofweek.apply(lambda x: 1 if x >=5 else 0)

# %%
daily_sales=df.groupby("order_date")["total_price"].sum().reset_index()
daily_sales
# Out:
#     order_date  total_price
# 0   2015-01-01     10424.00
# 1   2015-01-02     12536.05
# 2   2015-01-03      6304.10
# 3   2015-01-04      8221.25
# 4   2015-01-05      9921.10
# 5   2015-01-06     11923.65
# 6   2015-01-07      8262.00
# 7   2015-01-08      8811.10
# 8   2015-01-09      8758.35
# 9   2015-01-10     12347.00
# 10  2015-01-11      7521.00
# 11  2015-01-12      7683.50
# 12  2015-01-13      7758.85
# 13  2015-01-14      9095.00
# 14  2015-01-15      8033.25
# 15  2015-01-16      9643.75
# 16  2015-01-17      7924.10
# 17  2015-01-18      7258.25
# 18  2015-01-19      8745.85
# 19  2015-01-20      8840.45
# 20  2015-01-21      7714.85
# 21  2015-01-22      9337.70
# 22  2015-01-23      8896.25
# 23  2015-01-24      8682.45
# 24  2015-01-25      6360.30
# 25  2015-01-26      7206.60
# 26  2015-01-27      9432.45
# 27  2015-01-28      7794.95
# 28  2015-01-29      7191.35
# 29  2015-01-30      9001.35
# 30  2015-01-31      9487.10
# 31  2015-02-01     10001.00
# ...

# %%
daily_sales_quantity=df.groupby("order_date")["quantity"].sum().reset_index()
daily_sales_quantity
# Out:
#     order_date  quantity
# 0   2015-01-01       609
# 1   2015-01-02       723
# 2   2015-01-03       379
# 3   2015-01-04       496
# 4   2015-01-05       582
# 5   2015-01-06       696
# 6   2015-01-07       495
# 7   2015-01-08       541
# 8   2015-01-09       527
# 9   2015-01-10       729
# 10  2015-01-11       457
# 11  2015-01-12       477
# 12  2015-01-13       450
# 13  2015-01-14       528
# 14  2015-01-15       482
# 15  2015-01-16       576
# 16  2015-01-17       459
# 17  2015-01-18       435
# 18  2015-01-19       510
# 19  2015-01-20       524
# 20  2015-01-21       482
# 21  2015-01-22       575
# 22  2015-01-23       544
# 23  2015-01-24       528
# 24  2015-01-25       387
# 25  2015-01-26       424
# 26  2015-01-27       558
# 27  2015-01-28       448
# 28  2015-01-29       414
# 29  2015-01-30       536
# 30  2015-01-31       561
# 31  2015-02-01       591
# 32  2015-02-02       534
# 33  2015-02-03       540
# 34  2015-02-04       547
# 35  2015-02-05       556
# ...

# %%
df["day_of_week"]=df["order_date"].dt.day_name()
df["month"]=df["order_date"].dt.month_name()
df["year"]=df["order_date"].dt.year
df['week'] = df['order_date'].dt.isocalendar().week
df["quarter"]=df["order_date"].dt.quarter

# %%
df.head(10)
# Out:
#     pizza_id  order_id  pizza_name_id  quantity order_date   order_time  \
# 0          1         1     hawaiian_m         1 2015-01-01  11:38:36 AM
# 1          1         1     hawaiian_m         1 2015-01-01  11:38:36 AM
# 2          1         1     hawaiian_m         1 2015-01-01  11:38:36 AM
# 3          2         2  classic_dlx_m         1 2015-01-01  11:57:40 AM
# 6          2         2  classic_dlx_m         1 2015-01-01  11:57:40 AM
# 7          2         2  classic_dlx_m         1 2015-01-01  11:57:40 AM
# 8          3         2  five_cheese_l         1 2015-01-01  11:57:40 AM
# 13         3         2  five_cheese_l         1 2015-01-01  11:57:40 AM
# 14         4         2    ital_supr_l         1 2015-01-01  11:57:40 AM
# 16         4         2    ital_supr_l         1 2015-01-01  11:57:40 AM
#
#     unit_price  total_price pizza_size pizza_category  \
# 0        13.25        13.25          M        Classic
# 1        13.25        13.25          M        Classic
# ...

# %%
df["year"].value_counts()
# Out:
# year
# 2015    183722
# Name: count, dtype: int64

# %%
df["month"].value_counts()
# Out:
# month
# January      16132
# March        16109
# November     15988
# April        15897
# July         15798
# August       15579
# October      15328
# June         15315
# May          15173
# February     14459
# September    14259
# December     13685
# Name: count, dtype: int64

# %%
df["week"].value_counts()
# Out:
# week
# 48    4404
# 15    4123
# 2     4027
# 42    3913
# 20    3863
# 9     3846
# 32    3757
# 23    3733
# 14    3733
# 10    3721
# 45    3705
# 29    3685
# 40    3679
# 16    3665
# 6     3660
# 28    3644
# 37    3635
# 51    3630
# 26    3622
# 13    3616
# 17    3602
# 12    3583
# 38    3582
# 46    3578
# 30    3558
# 4     3550
# 24    3544
# 5     3532
# 41    3531
# 7     3529
# 31    3519
# 33    3507
# 34    3505
# 21    3503
# 25    3492
# 36    3490
# 11    3455
# 22    3434
# 8     3421
# 27    3419
# 3     3407
# 18    3395
# 47    3366
# 49    3291
# 43    3252
# 35    3234
# 50    3131
# 44    2932
# 19    2898
# 52    2573
# 39    2476
# 1     2207
# 53    1565
# Name: count, dtype: Int64

# %%
df["day_of_week"].value_counts()
# Out:
# day_of_week
# Friday       29226
# Saturday     27617
# Thursday     27413
# Wednesday    26054
# Tuesday      25655
# Monday       25010
# Sunday       22747
# Name: count, dtype: int64

# %%
week_48sales=df[df["week"]==48]

# %%
grouped_48week_price=week_48sales.groupby("day_of_week")["total_price"].sum().reset_index()
grouped_48week_price
# Out:
#   day_of_week  total_price
# 0      Friday     16605.35
# 1      Monday      9060.55
# 2    Saturday      7887.35
# 3      Sunday      6833.60
# 4    Thursday     17129.25
# 5     Tuesday      8879.60
# 6   Wednesday      8620.35

# %%
grouped_48week_quantity=week_48sales.groupby("day_of_week")["quantity"].sum().reset_index()
grouped_48week_quantity
# Out:
#   day_of_week  quantity
# 0      Friday       972
# 1      Monday       528
# 2    Saturday       456
# 3      Sunday       412
# 4    Thursday      1012
# 5     Tuesday       512
# 6   Wednesday       512

# %%
grouped_pizza=week_48sales.groupby("pizza_name")["quantity"].sum().reset_index()
grouped_pizza
# Out:
#                                     pizza_name  quantity
# 0                   The Barbecue Chicken Pizza       221
# 1                           The Big Meat Pizza       111
# 2                         The Brie Carre Pizza        52
# 3                          The Calabrese Pizza        96
# 4                 The California Chicken Pizza       254
# 5                    The Chicken Alfredo Pizza        95
# 6                      The Chicken Pesto Pizza        56
# 7                     The Classic Deluxe Pizza       198
# 8                        The Five Cheese Pizza        48
# 9                        The Four Cheese Pizza       223
# 10                             The Greek Pizza       193
# 11                      The Green Garden Pizza        69
# 12                          The Hawaiian Pizza       174
# 13                 The Italian Capocollo Pizza       136
# 14                   The Italian Supreme Pizza       156
# ...

# %%
total_quantity=week_48sales["quantity"].sum()
print(f" the total quantity of 48 th week is {total_quantity}")
# Out:
#  the total quantity of 48 th week is 4404

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Prepare daily sales data
daily_sales = df.groupby(df['order_date'].dt.date)['total_price'].sum()
daily_sales.index = pd.to_datetime(daily_sales.index)
daily_sales = daily_sales.resample('D').sum().fillna(0).asfreq('D')

# Apply seasonal decomposition
result = seasonal_decompose(daily_sales, model='additive')

# Plot the results
fig, axes = plt.subplots(3, 1, figsize=(14, 10))
titles = ['Observed', 'Trend', 'Seasonal']
for i, component in enumerate([result.observed, result.trend, result.seasonal]):
    component.plot(ax=axes[i], title=titles[i], xlabel='Date', ylabel='Sales', fontsize=14)
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Convert to datetime format
df['order_time'] = pd.to_datetime(df['order_time'], format='%I:%M:%S %p')

# Extract AM or PM using dt.strftime
df['period'] = df['order_time'].dt.strftime('%p')  # Returns 'AM' or 'PM'

# Count the number of AM and PM orders
order_counts = df['period'].value_counts()

print(order_counts)
# Out:
# period
# PM    173630
# AM     10092
# Name: count, dtype: int64

# %%
df.to_csv("dominos_pizzadata")

# %%
df.head(10)
# Out:
#     pizza_id  order_id  pizza_name_id  quantity order_date  \
# 0          1         1     hawaiian_m         1 2015-01-01
# 1          1         1     hawaiian_m         1 2015-01-01
# 2          1         1     hawaiian_m         1 2015-01-01
# 3          2         2  classic_dlx_m         1 2015-01-01
# 6          2         2  classic_dlx_m         1 2015-01-01
# 7          2         2  classic_dlx_m         1 2015-01-01
# 8          3         2  five_cheese_l         1 2015-01-01
# 13         3         2  five_cheese_l         1 2015-01-01
# 14         4         2    ital_supr_l         1 2015-01-01
# 16         4         2    ital_supr_l         1 2015-01-01
#
#             order_time  unit_price  total_price pizza_size pizza_category  \
# 0  1900-01-01 11:38:36       13.25        13.25          M        Classic
# 1  1900-01-01 11:38:36       13.25        13.25          M        Classic
# 2  1900-01-01 11:38:36       13.25        13.25          M        Classic
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("/content/dominos_pizzadata")

# Grouping data by category and size
category_size_sales = df.groupby(['pizza_category', 'pizza_size'])['total_price'].sum().reset_index()

# Plotting
plt.figure(figsize=(10,6))
sns.barplot(x='pizza_size', y='total_price', hue='pizza_category', data=category_size_sales)
plt.title('Total Sales by Pizza Category and Size')
plt.xlabel('Pizza Size')
plt.ylabel('Total Sales')
plt.legend(title='Pizza Category')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample loading
df = pd.read_csv("/content/dominos_pizzadata")

# Ensure order_date is in datetime format
df['order_date'] = pd.to_datetime(df['order_date'])

# Extract month and year
df['year_month'] = df['order_date'].dt.to_period('M')

# Group by month and category, and sum the total sales
monthly_sales = df.groupby(['year_month', 'pizza_category'])['total_price'].sum().reset_index()

# Optional: convert year_month to string for better formatting
monthly_sales['year_month'] = monthly_sales['year_month'].astype(str)

# Create a seaborn barplot to visualize the monthly sales by pizza category
plt.figure(figsize=(12, 6))
sns.barplot(data=monthly_sales, x='year_month', y='total_price', hue='pizza_category')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Set labels and title
plt.xlabel('Month-Year')
plt.ylabel('Total Sales')
plt.title('Monthly Pizza Sales by Category')

# Show the plot
plt.tight_layout()
plt.show()

# %%
weekly_sales =df.groupby(['day_of_week', 'pizza_category'])['quantity'].sum().unstack()

# Plotting
ax = weekly_sales.plot(kind='bar', figsize=(14, 7))
plt.xlabel('Weekday')
plt.ylabel('Total Quantity Sold')
plt.title('Weekly Sales by Pizza Category')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.legend(title='Pizza Category')

# Adding the count labels on top of each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge')

plt.show()

# %%
monthly_sales =df.groupby(['month', 'pizza_category',"pizza_size"])['quantity'].sum().unstack()

# Plotting
ax = monthly_sales.plot(kind='bar', figsize=(14, 7))
plt.xlabel('month')
plt.ylabel('Total Quantity Sold')
plt.title('Monthly Sales by Pizza Category')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.legend(title='Pizza Category')



plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'pizza_id', 'order_id', 'pizza_name_id', 'quantity',
#        'order_date', 'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name',
#        'Items_Qty_In_Grams', 'holiday', 'workingday', 'day_of_week', 'month',
#        'year', 'week', 'quarter', 'period'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample loading

df = pd.read_csv("/content/dominos_pizzadata")
# Ensure order_date is in datetime format
df['order_date'] = pd.to_datetime(df['order_date'])

# Group by pizza category (or pizza name if available) and sum the total sales
pizza_sales = df.groupby('pizza_name')['total_price'].sum().reset_index()

# Sort by total sales in descending order
top_pizza_sales = pizza_sales.sort_values(by='total_price', ascending=False).head(10)

# Create a seaborn barplot to visualize the top 10 selling pizzas
plt.figure(figsize=(12, 6))
sns.barplot(data=top_pizza_sales, x='pizza_name', y='total_price')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Set labels and title
plt.xlabel('Pizza Name')
plt.ylabel('Total Sales')
plt.title('Top 10 Most Selling Pizzas')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df.head(2)
# Out:
#    Unnamed: 0  pizza_id  order_id pizza_name_id  quantity  order_date  \
# 0           0         1         1    hawaiian_m         1  2015-01-01
# 1           1         1         1    hawaiian_m         1  2015-01-01
#
#             order_time  unit_price  total_price pizza_size  ...  \
# 0  1900-01-01 11:38:36       13.25        13.25          M  ...
# 1  1900-01-01 11:38:36       13.25        13.25          M  ...
#
#            pizza_name Items_Qty_In_Grams holiday  workingday  day_of_week  \
# 0  The Hawaiian Pizza                 40       1           0     Thursday
# 1  The Hawaiian Pizza                 30       1           0     Thursday
#
#      month  year week  quarter  period
# 0  January  2015    1        1      AM
# 1  January  2015    1        1      AM
#
# [2 rows x 22 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Count the number of AM and PM orders
order_counts = df['period'].value_counts()

# Visualization
plt.figure(figsize=(6, 4))
order_counts.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Count of Orders for AM and PM')
plt.xlabel('Period')
plt.ylabel('Order Count')
plt.xticks(rotation=0)
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'pizza_id', 'order_id', 'pizza_name_id', 'quantity',
#        'order_date', 'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name',
#        'Items_Qty_In_Grams', 'holiday', 'workingday', 'day_of_week', 'month',
#        'year', 'week', 'quarter', 'period'],
#       dtype='object')

# %%
monthly_data = df.groupby('month')['total_price'].sum().reset_index()  # Replace SALES with your column name
monthly_data['month'] = monthly_data['month'].astype(str)  # Convert back to string for plotting

plt.figure(figsize=(10, 6))
plt.plot(monthly_data['month'], monthly_data['total_price'], marker='o', linestyle='-', color='teal')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(df['workingday'].dtype)
print(df['workingday'].unique())
print(df['workingday'].value_counts())
# Out:
# int64
# [0 1]
# workingday
# 0    133358
# 1     50364
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='workingday', data=df)
plt.title("Count of Working vs Non-Working Days")
plt.xlabel("Working Day")
plt.ylabel("Count")
plt.show()

# %%
monthly_sales = df.groupby(["pizza_category", "year", "month"])['total_price'].sum().reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(data=monthly_sales, x='month', y='total_price', hue='pizza_category', marker='o')
plt.title('Monthly Total Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #TRAINING A MODEL

# %%
from prophet import Prophet
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
pizza=pd.read_csv("/content/dominos_pizzadata")

# %%
pizza.columns
# Out:
# Index(['Unnamed: 0', 'pizza_id', 'order_id', 'pizza_name_id', 'quantity',
#        'order_date', 'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name',
#        'Items_Qty_In_Grams', 'holiday', 'workingday', 'day_of_week', 'month',
#        'year', 'week', 'quarter', 'period'],
#       dtype='object')

# %%
def prepare_weekly_sales(df):
  if "order_date" not in pizza.columns:
    raise ValueError("The DataFrame must have a 'order_date' column.")
  if "pizza_name_id" not in pizza.columns:
    raise ValueError("The DataFrame must have a 'pizza_name_id' column.")

  df["order_date"]=pd.to_datetime(df["order_date"])
  df["week"]=df["order_date"].dt.to_period("W").apply(lambda r:r.start_time)
  weeklysales=df.groupby(["week","pizza_name_id"])["quantity"].sum().reset_index()
  weeklysales.rename(columns={"week":"ds","quantity":"y"},inplace=True)
  return weeklysales

# %%
dominos=prepare_weekly_sales(pizza)
dominos.head()
# Out:
#           ds pizza_name_id   y
# 0 2014-12-29     bbq_ckn_l  60
# 1 2014-12-29     bbq_ckn_m  65
# 2 2014-12-29     bbq_ckn_s   6
# 3 2014-12-29    big_meat_s  48
# 4 2014-12-29  brie_carre_s  16

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape


def train_models_for_all_pizza(dominos):
  pizza_models={}
  pizza_forecast={}
  pizza_mape_scores=[]

  for pizza_id in dominos["pizza_name_id"].unique():
    pizza_df=dominos[dominos["pizza_name_id"]==pizza_id]

    train_size=int(len(pizza_df)*0.8)
    train,test=pizza_df[:train_size],pizza_df[train_size:]


    model=Prophet()
    model.fit(train)

    future=model.make_future_dataframe(periods=len(test),freq="W")
    forecast=model.predict(future)


    prediction=forecast["yhat"][-len(test):].values
    prophet_mape=mape(test["y"].values,prediction)
    pizza_mape_scores.append({"pizza_name_id":pizza_id,"mape":prophet_mape})

    pizza_models[pizza_id]=model
    pizza_forecast[pizza_id]=forecast[["ds","yhat"]].tail(len(test)).reset_index(drop=True)


  all_forecast=pd.concat([pd.DataFrame({"pizza_name_id":pizza_id,"ds":pizza_forecast[pizza_id]["ds"],"yhat":pizza_forecast[pizza_id]["yhat"]})  for pizza_id in pizza_forecast],ignore_index=True)

  return pizza_models,pizza_mape_scores,all_forecast

# %%
pizza_models,pizza_mape_scores,all_forecast=train_models_for_all_pizza(dominos)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2m8ybk_j/p7gn_qce.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp2m8ybk_j/k69hfv31.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64984', 'data', 'file=/tmp/tmp2m8ybk_j/p7gn_qce.json', 'init=/tmp/tmp2m8ybk_j/k69hfv31.json', 'output', 'file=/tmp/tmp2m8ybk_j/prophet_model6w08luwh/prophet_model-20250413102057.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 10:20:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ...

# %%
import pickle

# assuming your model is named `model`
with open('pizza_model.pkl', 'wb') as file:
    pickle.dump(pizza_models, file)
print("Model saved as 'pizza_model.pkl'")
# Out:
# Model saved as 'pizza_model.pkl'

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_percentage_error

# Load model
with open('pizza_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

for item in pizza_mape_scores: # Print MAPE for each pizza type
    print(f'Pizza {item["pizza_name_id"]}: MAPE = {item["mape"]:.2f}')

pizza_mape_df=pd.DataFrame(pizza_mape_scores)
# Out:
# Pizza bbq_ckn_l: MAPE = 0.40
# Pizza bbq_ckn_m: MAPE = 0.50
# Pizza bbq_ckn_s: MAPE = 0.36
# Pizza big_meat_s: MAPE = 0.39
# Pizza brie_carre_s: MAPE = 0.37
# Pizza calabrese_l: MAPE = 0.43
# Pizza calabrese_m: MAPE = 0.55
# Pizza cali_ckn_l: MAPE = 0.46
# Pizza cali_ckn_m: MAPE = 0.30
# Pizza cali_ckn_s: MAPE = 0.44
# Pizza ckn_alfredo_l: MAPE = 0.75
# Pizza ckn_alfredo_m: MAPE = 0.32
# Pizza ckn_alfredo_s: MAPE = 0.64
# Pizza ckn_pesto_l: MAPE = 0.74
# Pizza ckn_pesto_m: MAPE = 0.54
# Pizza ckn_pesto_s: MAPE = 0.49
# Pizza classic_dlx_l: MAPE = 0.18
# Pizza classic_dlx_m: MAPE = 0.24
# Pizza classic_dlx_s: MAPE = 0.34
# Pizza five_cheese_l: MAPE = 0.23
# Pizza four_cheese_l: MAPE = 0.31
# Pizza four_cheese_m: MAPE = 0.48
# Pizza green_garden_l: MAPE = 0.50
# Pizza green_garden_m: MAPE = 0.57
# Pizza green_garden_s: MAPE = 0.36
# Pizza hawaiian_l: MAPE = 0.37
# Pizza hawaiian_m: MAPE = 0.67
# Pizza hawaiian_s: MAPE = 0.28
# Pizza ital_cpcllo_l: MAPE = 0.82
# ...

# %% [markdown]
# #INGREDIENTS AND PURCHASE ORDER CREATION

# %%
import pandas as pd

# %%
ingridients_per_pizza=pd.read_csv('/content/dominos_pizzadata')

# %%
ingridients_per_pizza.columns
# Out:
# Index(['Unnamed: 0', 'pizza_id', 'order_id', 'pizza_name_id', 'quantity',
#        'order_date', 'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name',
#        'Items_Qty_In_Grams', 'holiday', 'workingday', 'day_of_week', 'month',
#        'year', 'week', 'quarter', 'period'],
#       dtype='object')

# %%
ingredients_demand=pd.merge(all_forecast,ingridients_per_pizza,on="pizza_name_id",how="inner")

# %%
ingredients_demand["total_quantity_required"]=ingredients_demand["yhat"]*ingredients_demand["quantity"]
ingredients_demand.head(5)
# Out:
#   pizza_name_id         ds       yhat  Unnamed: 0  pizza_id  order_id  \
# 0     bbq_ckn_l 2015-10-18  78.475288         154        26        11
# 1     bbq_ckn_l 2015-10-18  78.475288         155        26        11
# 2     bbq_ckn_l 2015-10-18  78.475288         156        26        11
# 3     bbq_ckn_l 2015-10-18  78.475288         157        26        11
# 4     bbq_ckn_l 2015-10-18  78.475288         158        26        11
#
#    quantity  order_date           order_time  unit_price  ...  \
# 0         1  2015-01-01  1900-01-01 13:02:59       20.75  ...
# 1         1  2015-01-01  1900-01-01 13:02:59       20.75  ...
# 2         1  2015-01-01  1900-01-01 13:02:59       20.75  ...
# 3         1  2015-01-01  1900-01-01 13:02:59       20.75  ...
# 4         1  2015-01-01  1900-01-01 13:02:59       20.75  ...
#
#    Items_Qty_In_Grams holiday workingday day_of_week    month  year  week  \
# 0                  40       1          0    Thursday  January  2015     1
# ...

# %%
total_ingridient_demand=ingredients_demand.groupby("pizza_name_id")["total_quantity_required"].sum().reset_index()

# %%
total_ingridient_demand=total_ingridient_demand.sort_values(by="total_quantity_required",ascending=False)
total_ingridient_demand["total_quantity_reqkg"]=total_ingridient_demand["total_quantity_required"]/1000

# %%
purchase_order=pd.merge(total_ingridient_demand,ingridients_per_pizza[["pizza_name_id","pizza_ingredients","pizza_name","Items_Qty_In_Grams"]].drop_duplicates(),on="pizza_name_id",how="left")

# %%
purchase_order=purchase_order.rename(columns={"pizza_name_id":"pizzatype","total_quantity_reqkg":"Ingridients (kg)"})

# %%
purchase_order.columns
# Out:
# Index(['pizzatype', 'total_quantity_required', 'Ingridients (kg)',
#        'pizza_ingredients', 'pizza_name', 'Items_Qty_In_Grams'],
#       dtype='object')

# %%
purchase_order=purchase_order.groupby(["pizzatype","pizza_name","pizza_ingredients"])["Ingridients (kg)"].sum().reset_index()

# %%
purchase_order=purchase_order.sort_values(by="Ingridients (kg)",ascending=False)
purchase_order
# Out:
#          pizzatype                                  pizza_name  \
# 21   four_cheese_l                       The Four Cheese Pizza
# 68    spicy_ital_l                     The Spicy Italian Pizza
# 65    southw_ckn_l                 The Southwest Chicken Pizza
# 80      thai_ckn_l                      The Thai Chicken Pizza
# 1        bbq_ckn_m                  The Barbecue Chicken Pizza
# ..             ...                                         ...
# 47   pep_msh_pep_l  The Pepperoni, Mushroom, and Peppers Pizza
# 23  green_garden_l                      The Green Garden Pizza
# 13   ckn_alfredo_s                   The Chicken Alfredo Pizza
# 7      calabrese_s                         The Calabrese Pizza
# 49   pep_msh_pep_s  The Pepperoni, Mushroom, and Peppers Pizza
#
#                                     pizza_ingredients  Ingridients (kg)
# 21  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...      41602.421657
# ...
